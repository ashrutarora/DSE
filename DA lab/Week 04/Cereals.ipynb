# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

# %%
missing_values = ["-1"]
df = pd.read_excel("cereals1.xls", na_values = missing_values)

# %%
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0           100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 1                    All-Bran   K    C        70        4    1     260    9.0
# 2   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 3              Almond_Delight   R    C       110        2    2     200    1.0
# 4     Apple_Cinnamon_Cheerios   G    C       110        2    2     180    1.5
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 71                    Triples   G    C       110        2    1     250    0.0
# 72                       Trix   G    C       110        1    1     140    0.0
# 73                 Wheat_Chex   R    C       100        3    1     230    3.0
# 74                   Wheaties   G    C       100        3    1     200    3.0
# 75        Wheaties_Honey_Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
# 5 number summary of all the numeric attributes

df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   76.000000  76.000000  76.000000   76.000000  76.000000  75.000000
# mean   107.368421   2.526316   1.013158  160.065789   2.048684  14.933333
# std     19.139378   1.089020   1.013159   84.318813   2.219038   3.762666
# min     50.000000   1.000000   0.000000    0.000000   0.000000   7.000000
# 25%    100.000000   2.000000   0.000000  132.500000   0.750000  12.000000
# 50%    110.000000   2.500000   1.000000  180.000000   1.750000  15.000000
# 75%    110.000000   3.000000   2.000000  212.500000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  75.000000   74.000000   76.000000  76.000000  76.000000  76.000000
# mean    7.040000   96.216216   28.289474   2.197368   1.030000   0.827500
# std     4.406506   67.594737   22.487813   0.832982   0.151438   0.227204
# ...

# %%
df = df.fillna(df.mean())
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0           100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 1                    All-Bran   K    C        70        4    1     260    9.0
# 2   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 3              Almond_Delight   R    C       110        2    2     200    1.0
# 4     Apple_Cinnamon_Cheerios   G    C       110        2    2     180    1.5
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 71                    Triples   G    C       110        2    1     250    0.0
# 72                       Trix   G    C       110        1    1     140    0.0
# 73                 Wheat_Chex   R    C       100        3    1     230    3.0
# 74                   Wheaties   G    C       100        3    1     200    3.0
# 75        Wheaties_Honey_Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   76.000000  76.000000  76.000000   76.000000  76.000000  76.000000
# mean   107.368421   2.526316   1.013158  160.065789   2.048684  14.933333
# std     19.139378   1.089020   1.013159   84.318813   2.219038   3.737498
# min     50.000000   1.000000   0.000000    0.000000   0.000000   7.000000
# 25%    100.000000   2.000000   0.000000  132.500000   0.750000  12.000000
# 50%    110.000000   2.500000   1.000000  180.000000   1.750000  14.966667
# 75%    110.000000   3.000000   2.000000  212.500000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  76.000000   76.000000   76.000000  76.000000  76.000000  76.000000
# mean    7.040000   96.216216   28.289474   2.197368   1.030000   0.827500
# std     4.377031   66.687384   22.487813   0.832982   0.151438   0.227204
# ...

# %%
df['fiber'].skew()
# Out:
# 2.5918343154055945

# %%
print(df['fiber'].quantile(0.50)) 
print(df['fiber'].quantile(0.95))
# Out:
# 1.75
# 5.0

# %%
df['fiber'] = np.where(df['fiber'] > df['fiber'].quantile(0.95), df['fiber'].quantile(0.50), df['fiber'])
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0           100%_Natural_Bran   Q    C       120        3    5      15   2.00
# 1                    All-Bran   K    C        70        4    1     260   1.75
# 2   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   1.75
# 3              Almond_Delight   R    C       110        2    2     200   1.00
# 4     Apple_Cinnamon_Cheerios   G    C       110        2    2     180   1.50
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 71                    Triples   G    C       110        2    1     250   0.00
# 72                       Trix   G    C       110        1    1     140   0.00
# 73                 Wheat_Chex   R    C       100        3    1     230   3.00
# 74                   Wheaties   G    C       100        3    1     200   3.00
# 75        Wheaties_Honey_Gold   G    C       110        2    1     200   1.00
#
# ...

# %%
df['fiber'].skew()
# Out:
# 0.511636075832196

# %%
# 6) Cross tabulate the type of cereal (hot vs cold) against the manufacturer

pd.crosstab(df.type, df.mfr)
# Out:
# mfr   A   G   K  N  P  Q  R
# type
# C     0  22  23  4  9  7  8
# H     1   0   0  1  0  1  0

# %%
#7) Which is the cereal with the best rating, worst rating

best_Rating = df['rating'].max()
worst_Rating = df['rating'].min()

print("Best rating = ", best_Rating, "    Worst rating = ", worst_Rating )
# Out:
# Best rating =  93.704912     Worst rating =  18.042851

# %%
# 8) Plot a side-by-side boxplot comparing the consumer rating of hot vs. cold cereals
